# %% [markdown]
# # Polymorphism

# %% [markdown]
# ### Polymorphism in Python is a core concept of object-oriented programming (OOP) that allows the same function or method name to behave differently depending on the object (class) calling it.
#
# ### In simple words: One name, many forms.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
a = "Sarthak"
print(type(a))
print(len(a))
# Out:
# <class 'str'>
# 7

# %%
b = [12, 13, 14, 15]
print(type(b))
print(len(b))
# Out:
# <class 'list'>
# 4

# %%
c = (11, 12, 13)
print(type(c))
print(len(c))
# Out:
# <class 'tuple'>
# 3

# %%
d = {"a": 1, "b": 2, "c": 3, "d": 4}
print(type(d))
print(len(d))
# Out:
# <class 'dict'>
# 4

# %%
d = [12, 13, 14, 15, 16]
print(type(d))
print(sum(d))
# Out:
# <class 'list'>
# 70

# %%
e = (3, 4, 5, 6, 7, 8, 9)
print(type(e))
print(sum(e))
# Out:
# <class 'tuple'>
# 42

# %% [markdown]
# # Polymorphism in operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Integer addition
a = 3
b = 4
print(a + b)
# Out:
# 7

# %%
# Float addition
a = 12.5
b = 13.2
print(a + b)
# Out:
# 25.7

# %%
# String Concatenation
a = "String1"
b = "String2"
print(a + b)
# Out:
# String1String2

# %%
print(a + " " + b)
# Out:
# String1 String2

# %%
# List (merge 2 lists)
a = [1, 2, 3, 4]
b = [5, 6, 7]
print(a + b)
print(b + a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# [5, 6, 7, 1, 2, 3, 4]

# %%
a = 3
b = 4
print(a * b)
# Out:
# 12

# %%
a = 12.3
b = 11.5
print(a * b)
# Out:
# 141.45000000000002

# %%
a = "Sarthak"
print(a * 10)
# Out:
# SarthakSarthakSarthakSarthakSarthakSarthakSarthakSarthakSarthakSarthak

# %%
print("="*30)
# Out:
# ==============================

# %%
b = [1, 2, 3]
print(b * 3)
print(b * 5)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# # Polymorphism in classes

# %%
class India:

    def capital(self):
        print("New Delhi is capital of India")

    def language(self):
        print("Hindi is widely spoken in India")

# %%
class USA:

    def capital(self):
        print("Washington D.C. is capital of USA")
    
    def language(self):
        print("English is widely spoken in USA")

# %%
class France:

    def capital(self):
        print("Paris is capital of France")

    def language(self):
        print("French is widely spoken in France")

# %%
c1 = India()
print(type(c1))
c1.capital()
c1.language()
# Out:
# <class '__main__.India'>
# New Delhi is capital of India
# Hindi is widely spoken in India

# %%
c2 = USA()
print(type(c2))
c2.capital()
c2.language()
# Out:
# <class '__main__.USA'>
# Washington D.C. is capital of USA
# English is widely spoken in USA

# %%
c3 = France()
print(type(c3))
c3.capital()
c3.language()
# Out:
# <class '__main__.France'>
# Paris is capital of France
# French is widely spoken in France

# %%
countries = [India(), USA(), France()]

for c in countries:
    print(type(c))
    c.capital()
    c.language()
    print("=" * 40)
# Out:
# <class '__main__.India'>
# New Delhi is capital of India
# Hindi is widely spoken in India
# ========================================
# <class '__main__.USA'>
# Washington D.C. is capital of USA
# English is widely spoken in USA
# ========================================
# <class '__main__.France'>
# Paris is capital of France
# French is widely spoken in France
# ========================================

# %% [markdown]
# # Polymorphism in calculating area shape

# %%
from dataclasses import dataclass

@dataclass
class Rectangle:
    width : float
    height : float

    def perimeter(self) -> float:
        return 2 * (self.width + self.height)
    
    def area(self) -> float:
        return self.width * self.height

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
@dataclass
class Circle:
    radius: float

    def perimeter(self) -> float:
        return 2 * math.pi * self.radius
    
    def area(self) -> float:
        return math.pi * (self.radius ** 2)

# %%
s1 = Rectangle(width=50, height=20)
print(s1)
# Out:
# Rectangle(width=50, height=20)

# %%
s1.perimeter()
# Out:
# 140

# %%
s1.area()
# Out:
# 1000

# %%
s2 = Circle(radius=14)
print(s2)
# Out:
# Circle(radius=14)

# %%
s2.perimeter()
# Out:
# 87.96459430051421

# %%
s2.area()
# Out:
# 615.7521601035994

# %%
import math

class Triangle:

    def __init__(self, a: float, b: float, c: float):
        self.a = a
        self.b = b
        self.c = c
        # Check that sides of triangle are non zero and positive
        if a <= 0 or b <= 0 or c <= 0:
            raise ValueError("Sides of Triangle must be non zero and positive")
        # Check the triangle inequality
        if not self.is_triangle():
            raise ValueError("Triangle Inequality is Violated")
        
    def __str__(self):
        return f"Triangle(a = {self.a}, b = {self.b}, c = {self.c})"
    
    def is_triangle(self) -> bool :
        return (
            self.a + self.b > self.c and 
            self.b + self.c > self.a and 
            self.c + self.a > self.b 
        )
    
    def perimeter(self) -> float:
        return self.a + self.b + self.c
    
    def area(self) -> float:
        s = self.perimeter() / 2
        a = math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))
        return a

# %%
s3 = Triangle(a=11.0, b=12.0, c=13.0)
print(s3)
# Out:
# Triangle(a = 11.0, b = 12.0, c = 13.0)

# %%
s3.perimeter()
# Out:
# 36.0

# %%
s3.area()
# Out:
# 61.48170459575759

# %%
shapes = [
    Rectangle(width=12, height=5),
    Circle(radius=21),
    Triangle(a=12, b=13, c=14),
    Circle(radius=50),
    Triangle(a=3, b=4, c=5),
    Rectangle(width=50, height=35)
]

for s in shapes:
    print(s)
    p = s.perimeter()
    a = s.area()
    print(f"Perimeter : {p:.2f}")
    print(f"Area : {a:.2f}")
    print("=" * 50)
# Out:
# Rectangle(width=12, height=5)
# Perimeter : 34.00
# Area : 60.00
# ==================================================
# Circle(radius=21)
# Perimeter : 131.95
# Area : 1385.44
# ==================================================
# Triangle(a = 12, b = 13, c = 14)
# Perimeter : 39.00
# Area : 72.31
# ==================================================
# Circle(radius=50)
# Perimeter : 314.16
# Area : 7853.98
# ==================================================
# Triangle(a = 3, b = 4, c = 5)
# Perimeter : 12.00
# Area : 6.00
# ==================================================
# Rectangle(width=50, height=35)
# Perimeter : 170.00
# Area : 1750.00
# ==================================================

# %% [markdown]
# # Assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

class Triangle:

    def __init__(self, a: float, b: float, c: float):
        self.a = a
        self.b = b
        self.c = c
        # Check that sides of triangle are non zero and positive
        if a <= 0 or b <= 0 or c <= 0:
            raise ValueError("Sides of Triangle must be non zero and positive")
        # Check the triangle inequality
        if not self.is_triangle():
            raise ValueError("Triangle Inequality is Violated")
        
    def __str__(self):
        return f"Triangle(a = {self.a}, b = {self.b}, c = {self.c})"
    
    def is_triangle(self) -> bool :
        return (
            self.a + self.b > self.c and 
            self.b + self.c > self.a and 
            self.c + self.a > self.b 
        )
    
    def perimeter(self) -> float:
        return self.a + self.b + self.c
    
    def area(self) -> float:
        s = self.perimeter() / 2
        a = math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))
        return a

# %%
t1 = Triangle(a=3.0, b=4.0, c=5.0)
print(type(t1))
# Out:
# <class '__main__.Triangle'>

# %%
print(t1)
# Out:
# Triangle(a = 3.0, b = 4.0, c = 5.0)

# %%
t1.a
# Out:
# 3.0

# %%
t1.b
# Out:
# 4.0

# %%
t1.c
# Out:
# 5.0

# %%
t1.is_triangle()
# Out:
# True

# %%
t1.perimeter()
# Out:
# 12.0

# %%
t1.area()
# Out:
# 6.0

# %%
t2 = Triangle(a=1, b=2, c=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t2 = Triangle(a=1, b=2, c=3)
#
# Cell In[1], line 14, in Triangle.__init__(self, a, b, c)
#      12 # Check the triangle inequality
#      13 if not self.is_triangle():
# ---> 14     raise ValueError("Triangle Inequality is Violated")
#
# ValueError: Triangle Inequality is Violated

# %%
t2 = Triangle(a=2, b=3, c=6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t2 = Triangle(a=2, b=3, c=6)
#
# Cell In[1], line 14, in Triangle.__init__(self, a, b, c)
#      12 # Check the triangle inequality
#      13 if not self.is_triangle():
# ---> 14     raise ValueError("Triangle Inequality is Violated")
#
# ValueError: Triangle Inequality is Violated

# %%
t2 = Triangle(a=0, b=1, c=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t2 = Triangle(a=0, b=1, c=2)
#
# Cell In[1], line 11, in Triangle.__init__(self, a, b, c)
#       9 # Check that sides of triangle are non zero and positive
#      10 if a <= 0 or b <= 0 or c <= 0:
# ---> 11     raise ValueError("Sides of Triangle must be non zero and positive")
#      12 # Check the triangle inequality
#      13 if not self.is_triangle():
#
# ValueError: Sides of Triangle must be non zero and positive

# %%
t2 = Triangle(a=-3, b=4, c=-5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t2 = Triangle(a=-3, b=4, c=-5)
#
# Cell In[1], line 11, in Triangle.__init__(self, a, b, c)
#       9 # Check that sides of triangle are non zero and positive
#      10 if a <= 0 or b <= 0 or c <= 0:
# ---> 11     raise ValueError("Sides of Triangle must be non zero and positive")
#      12 # Check the triangle inequality
#      13 if not self.is_triangle():
#
# ValueError: Sides of Triangle must be non zero and positive

# %%
t2 = Triangle(a=12.0, b=13.0, c=14.0)
print(type(t2))
# Out:
# <class '__main__.Triangle'>

# %%
print(t2)
# Out:
# Triangle(a = 12.0, b = 13.0, c = 14.0)

# %%
t2.a
# Out:
# 12.0

# %%
t2.b
# Out:
# 13.0

# %%
t2.c
# Out:
# 14.0

# %%
t2.is_triangle()
# Out:
# True

# %%
t2.perimeter()
# Out:
# 39.0

# %%
t2.area()
# Out:
# 72.30793524918272

# %%
tr = [
    Triangle(a=3.0, b=4.0, c=5.0),
    Triangle(a=12.0, b=13.0, c=14.0),
    Triangle(a=11.0, b=12.0, c=13.0),
    Triangle(a=21.0, b=23.0, c=25.0),
    Triangle(a = 11.5, b=12.9, c=14.8)
]

for t in tr:
    print(t)
    p = t.perimeter()
    a = t.area()
    print(f"Perimeter : {p:.2f}")
    print(f"Area : {a:.2f}")
    print("=" * 50)
# Out:
# Triangle(a = 3.0, b = 4.0, c = 5.0)
# Perimeter : 12.00
# Area : 6.00
# ==================================================
# Triangle(a = 12.0, b = 13.0, c = 14.0)
# Perimeter : 39.00
# Area : 72.31
# ==================================================
# Triangle(a = 11.0, b = 12.0, c = 13.0)
# Perimeter : 36.00
# Area : 61.48
# ==================================================
# Triangle(a = 21.0, b = 23.0, c = 25.0)
# Perimeter : 69.00
# Area : 225.57
# ==================================================
# Triangle(a = 11.5, b = 12.9, c = 14.8)
# Perimeter : 39.20
# Area : 71.45
# ==================================================
